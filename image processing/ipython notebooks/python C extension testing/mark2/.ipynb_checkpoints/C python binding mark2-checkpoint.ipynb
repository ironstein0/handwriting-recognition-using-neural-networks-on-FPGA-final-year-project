# %%
working_directory = '/users/ironstein/documents/projects working directory/handwriting recognition using neural networks on FPGA final year project/image processing/ipython notebooks/python C extension testing/mark2'

import os
import time

os.chdir(working_directory)

# %%
# %%file test.c
#
# #include <stdio.h>
#
# void for_loop_test(int n) {
#     int i;
#     for(i=0;i<n;i++);
# }
# Out:
# Overwriting test.c

# %% [markdown]
# ###generating shared object for the above C file (test.so)

# %%
os.system('cd ' + working_directory)
# !clang -c test.c
# !clang -o test.so -shared test.c
# !file test.so
# Out:
# test.so: Mach-O 64-bit dynamically linked shared library x86_64

# %% [markdown]
# ###python file to access the functions in test.so shared library

# %%
# %%file _test.py

import numpy
import ctypes

_test_ = numpy.ctypeslib.load_library('test','.')
_test_.for_loop_test.argtypes = [ctypes.c_int]
_test_.for_loop_test.restype = ctypes.c_void_p

def C_for_test(n) : 
    _test_.for_loop_test(n)
# Out:
# Overwriting _test.py

# %%
def Python_for_test(n) : 
    for i in range(n) : 
        pass

# %% [markdown]
# ###decorator for calculating time of execution of a function

# %%
def time_this_function(function) : 
    try : 
        time
    except : 
        import time
    
    def wrapper_function(*args,**kwargs) : 
        start_time = time.time()
        function(*args,**kwargs)
        print((time.time() - start_time)*1000000,end=' ms\n')
        
    return wrapper_function

# %% [markdown]
# ###testing Python and C functions for comparing the performance

# %%
import _test

@time_this_function
def C_for_test(n) : 
    _test.C_for_test(n)
    
@time_this_function
def Python_for_test(n) : 
    Python_for_test(n)

# %%
C_for_test(1000)
# Out:
# 20.9808349609375 ms

# %%
Python_for_test(1000)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-be3e5e3dacad> in <module>()
# ----> 1 Python_for_test(1000)
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
# ...
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# <ipython-input-12-19edd4276a01> in Python_for_test(n)
#       7 @time_this_function
#       8 def Python_for_test(n) :
# ----> 9     Python_for_test(n)
#      10
#
# <ipython-input-6-66daac89315d> in wrapper_function(*args, **kwargs)
#       7     def wrapper_function(*args,**kwargs) :
#       8         start_time = time.time()
# ----> 9         function(*args,**kwargs)
#      10         print((time.time() - start_time)*1000000,end=' ms\n')
#      11
#
# RuntimeError: maximum recursion depth exceeded while calling a Python object
